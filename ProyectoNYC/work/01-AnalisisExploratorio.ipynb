# %% [markdown]
# # Descripcion del Proyecto

# %% [markdown]
# ## Importacion de Pandas y el .cvs

# %%
import pandas as pd

# %%
df = pd.read_csv('../Datasets/Air_Quality.csv', sep=',')

# %% [markdown]
# 1.	¿El conjunto de datos que tengo realmente me sirve para responder algunas de las preguntas que plantee?
# 2.	¿qué tamaño de mi conjunto de datos, serán datos suficientes?
# 3.	¿qué columnas tengo y que información tengo?
# 4.	¿los nombres que tiene mis colunas son el nombre más apropiado?
# 5.	¿qué tipo de datos tengo en cada columna?, ¿parece ser los tipos de dato correcto o son incorrectos?
# 6.	Si seleccione una algunas filas al azar y las observo ¿estoy obteniendo los datos que debería o hay datos que están sucios?

# %% [markdown]
# # Analisis Exploratorio de Dato

# %%
df.head(5)
# Out:
#    Unique ID  Indicator ID                  Name Measure Measure Info  \
# 0     216498           386            Ozone (O3)    Mean          ppb
# 1     216499           386            Ozone (O3)    Mean          ppb
# 2     219969           386            Ozone (O3)    Mean          ppb
# 3     219970           386            Ozone (O3)    Mean          ppb
# 4     164876           383  Sulfur Dioxide (SO2)    Mean          ppb
#
#   Geo Type Name  Geo Join ID                    Geo Place Name  \
# 0            CD          313               Coney Island (CD13)
# 1            CD          313               Coney Island (CD13)
# 2       Borough            1                             Bronx
# 3       Borough            1                             Bronx
# 4            CD          211  Morris Park and Bronxdale (CD11)
#
#       Time Period  Start_Date  Data Value  Message
# 0     Summer 2013  06/01/2013       34.64      NaN
# 1     Summer 2014  06/01/2014       33.22      NaN
# 2     Summer 2013  06/01/2013       31.25      NaN
# 3     Summer 2014  06/01/2014       31.15      NaN
# 4  Winter 2008-09  12/01/2008        5.89      NaN

# %%
df.shape
# Out:
# (16122, 12)

# %%
df.dtypes
# Out:
# Unique ID           int64
# Indicator ID        int64
# Name               object
# Measure            object
# Measure Info       object
# Geo Type Name      object
# Geo Join ID         int64
# Geo Place Name     object
# Time Period        object
# Start_Date         object
# Data Value        float64
# Message           float64
# dtype: object

# %%
df.columns
# Out:
# Index(['Unique ID', 'Indicator ID', 'Name', 'Measure', 'Measure Info',
#        'Geo Type Name', 'Geo Join ID', 'Geo Place Name', 'Time Period',
#        'Start_Date', 'Data Value', 'Message'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16122 entries, 0 to 16121
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unique ID       16122 non-null  int64
#  1   Indicator ID    16122 non-null  int64
#  2   Name            16122 non-null  object
#  3   Measure         16122 non-null  object
#  4   Measure Info    16122 non-null  object
#  5   Geo Type Name   16122 non-null  object
#  6   Geo Join ID     16122 non-null  int64
#  7   Geo Place Name  16122 non-null  object
#  8   Time Period     16122 non-null  object
#  9   Start_Date      16122 non-null  object
#  10  Data Value      16122 non-null  float64
#  11  Message         0 non-null      float64
# dtypes: float64(2), int64(3), object(7)
# memory usage: 1.5+ MB

# %%
df.describe()
# Out:
#            Unique ID  Indicator ID   Geo Join ID    Data Value  Message
# count   16122.000000  16122.000000  1.612200e+04  16122.000000      0.0
# mean   339480.955589    427.131063  6.133394e+05     19.129163      NaN
# std    194099.809551    109.657607  7.916715e+06     21.673789      NaN
# min    130355.000000    365.000000  1.000000e+00      0.000000      NaN
# 25%    172183.250000    365.000000  2.020000e+02      8.460000      NaN
# 50%    221882.500000    375.000000  3.030000e+02     13.900000      NaN
# 75%    547749.750000    386.000000  4.040000e+02     25.470000      NaN
# max    671122.000000    661.000000  1.051061e+08    424.700000      NaN

# %%
import numpy as np

# %%
df_2 = df
df_2
# Out:
#        Unique ID  Indicator ID                  Name Measure Measure Info  \
# 0         216498           386            Ozone (O3)    Mean          ppb
# 1         216499           386            Ozone (O3)    Mean          ppb
# 2         219969           386            Ozone (O3)    Mean          ppb
# 3         219970           386            Ozone (O3)    Mean          ppb
# 4         164876           383  Sulfur Dioxide (SO2)    Mean          ppb
# ...          ...           ...                   ...     ...          ...
# 16117     671118           386            Ozone (O3)    Mean          ppb
# 16118     671119           386            Ozone (O3)    Mean          ppb
# 16119     671120           386            Ozone (O3)    Mean          ppb
# 16120     671121           386            Ozone (O3)    Mean          ppb
# 16121     671122           386            Ozone (O3)    Mean          ppb
#
#       Geo Type Name  Geo Join ID                          Geo Place Name  \
# 0                CD          313                     Coney Island (CD13)
# 1                CD          313                     Coney Island (CD13)
# 2           Borough            1                                   Bronx
# 3           Borough            1                                   Bronx
# 4                CD          211        Morris Park and Bronxdale (CD11)
# ...             ...          ...                                     ...
# 16117            CD          306    Park Slope and Carroll Gardens (CD6)
# 16118            CD          305   East New York and Starrett City (CD5)
# 16119            CD          304                          Bushwick (CD4)
# 16120            CD          303                Bedford Stuyvesant (CD3)
# 16121            CD          302  Fort Greene and Brooklyn Heights (CD2)
#
#           Time Period  Start_Date  Data Value  Message
# 0         Summer 2013  06/01/2013       34.64      NaN
# 1         Summer 2014  06/01/2014       33.22      NaN
# 2         Summer 2013  06/01/2013       31.25      NaN
# 3         Summer 2014  06/01/2014       31.15      NaN
# 4      Winter 2008-09  12/01/2008        5.89      NaN
# ...               ...         ...         ...      ...
# 16117     Summer 2020  06/01/2020       28.70      NaN
# 16118     Summer 2020  06/01/2020       29.56      NaN
# 16119     Summer 2020  06/01/2020       29.65      NaN
# 16120     Summer 2020  06/01/2020       29.28      NaN
# 16121     Summer 2020  06/01/2020       28.93      NaN
#
# [16122 rows x 12 columns]

# %%
df_2.count()
# Out:
# Unique ID         16122
# Indicator ID      16122
# Name              16122
# Measure           16122
# Measure Info      16122
# Geo Type Name     16122
# Geo Join ID       16122
# Geo Place Name    16122
# Time Period       16122
# Start_Date        16122
# Data Value        16122
# Message               0
# dtype: int64

# %%
df_2.min()
# Out:
# Unique ID                                                    130355
# Indicator ID                                                    365
# Name              Air Toxics Concentrations- Average Benzene Con...
# Measure                                Annual Average Concentration
# Measure Info                                    mcg per cubic meter
# Geo Type Name                                               Borough
# Geo Join ID                                                       1
# Geo Place Name                   Bay Ridge and Dyker Heights (CD10)
# Time Period                                                    2005
# Start_Date                                               01/01/2005
# Data Value                                                      0.0
# Message                                                         NaN
# dtype: object

# %%
df_2.max()
# Out:
# Unique ID                                                    671122
# Indicator ID                                                    661
# Name              Traffic Density- Annual Vehicle Miles Traveled...
# Measure                                               million miles
# Measure Info                                                  µg/m3
# Geo Type Name                                                 UHF42
# Geo Join ID                                               105106107
# Geo Place Name                         Woodside and Sunnyside (CD2)
# Time Period                                          Winter 2019-20
# Start_Date                                               12/31/2015
# Data Value                                                    424.7
# Message                                                         NaN
# dtype: object

# %% [markdown]
# # Eliminacion de NaNs

# %%
df.isna()
# Out:
#        Unique ID  Indicator ID   Name  Measure  Measure Info  Geo Type Name  \
# 0          False         False  False    False         False          False
# 1          False         False  False    False         False          False
# 2          False         False  False    False         False          False
# 3          False         False  False    False         False          False
# 4          False         False  False    False         False          False
# ...          ...           ...    ...      ...           ...            ...
# 16117      False         False  False    False         False          False
# 16118      False         False  False    False         False          False
# 16119      False         False  False    False         False          False
# 16120      False         False  False    False         False          False
# 16121      False         False  False    False         False          False
#
#        Geo Join ID  Geo Place Name  Time Period  Start_Date  Data Value  \
# 0            False           False        False       False       False
# 1            False           False        False       False       False
# 2            False           False        False       False       False
# 3            False           False        False       False       False
# 4            False           False        False       False       False
# ...            ...             ...          ...         ...         ...
# 16117        False           False        False       False       False
# 16118        False           False        False       False       False
# 16119        False           False        False       False       False
# 16120        False           False        False       False       False
# 16121        False           False        False       False       False
#
#        Message
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
# ...        ...
# 16117     True
# 16118     True
# 16119     True
# 16120     True
# 16121     True
#
# [16122 rows x 12 columns]

# %%
df.isna().sum()
# Out:
# Unique ID             0
# Indicator ID          0
# Name                  0
# Measure               0
# Measure Info          0
# Geo Type Name         0
# Geo Join ID           0
# Geo Place Name        0
# Time Period           0
# Start_Date            0
# Data Value            0
# Message           16122
# dtype: int64

# %%
df.isna().sum(axis = 'columns')
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 16117    1
# 16118    1
# 16119    1
# 16120    1
# 16121    1
# Length: 16122, dtype: int64

# %%
df.isna().sum(axis = 'index')
# Out:
# Unique ID             0
# Indicator ID          0
# Name                  0
# Measure               0
# Measure Info          0
# Geo Type Name         0
# Geo Join ID           0
# Geo Place Name        0
# Time Period           0
# Start_Date            0
# Data Value            0
# Message           16122
# dtype: int64

# %% [markdown]
# # Eliminar NaNs

# %%
df_limpiar = df.copy()
df_limpiar
# Out:
#        Unique ID  Indicator ID                  Name Measure Measure Info  \
# 0         216498           386            Ozone (O3)    Mean          ppb
# 1         216499           386            Ozone (O3)    Mean          ppb
# 2         219969           386            Ozone (O3)    Mean          ppb
# 3         219970           386            Ozone (O3)    Mean          ppb
# 4         164876           383  Sulfur Dioxide (SO2)    Mean          ppb
# ...          ...           ...                   ...     ...          ...
# 16117     671118           386            Ozone (O3)    Mean          ppb
# 16118     671119           386            Ozone (O3)    Mean          ppb
# 16119     671120           386            Ozone (O3)    Mean          ppb
# 16120     671121           386            Ozone (O3)    Mean          ppb
# 16121     671122           386            Ozone (O3)    Mean          ppb
#
#       Geo Type Name  Geo Join ID                          Geo Place Name  \
# 0                CD          313                     Coney Island (CD13)
# 1                CD          313                     Coney Island (CD13)
# 2           Borough            1                                   Bronx
# 3           Borough            1                                   Bronx
# 4                CD          211        Morris Park and Bronxdale (CD11)
# ...             ...          ...                                     ...
# 16117            CD          306    Park Slope and Carroll Gardens (CD6)
# 16118            CD          305   East New York and Starrett City (CD5)
# 16119            CD          304                          Bushwick (CD4)
# 16120            CD          303                Bedford Stuyvesant (CD3)
# 16121            CD          302  Fort Greene and Brooklyn Heights (CD2)
#
#           Time Period  Start_Date  Data Value  Message
# 0         Summer 2013  06/01/2013       34.64      NaN
# 1         Summer 2014  06/01/2014       33.22      NaN
# 2         Summer 2013  06/01/2013       31.25      NaN
# 3         Summer 2014  06/01/2014       31.15      NaN
# 4      Winter 2008-09  12/01/2008        5.89      NaN
# ...               ...         ...         ...      ...
# 16117     Summer 2020  06/01/2020       28.70      NaN
# 16118     Summer 2020  06/01/2020       29.56      NaN
# 16119     Summer 2020  06/01/2020       29.65      NaN
# 16120     Summer 2020  06/01/2020       29.28      NaN
# 16121     Summer 2020  06/01/2020       28.93      NaN
#
# [16122 rows x 12 columns]

# %%
df_Dropped = df_limpiar.dropna(axis=1, how='all')
df_Dropped
# Out:
#        Unique ID  Indicator ID                  Name Measure Measure Info  \
# 0         216498           386            Ozone (O3)    Mean          ppb
# 1         216499           386            Ozone (O3)    Mean          ppb
# 2         219969           386            Ozone (O3)    Mean          ppb
# 3         219970           386            Ozone (O3)    Mean          ppb
# 4         164876           383  Sulfur Dioxide (SO2)    Mean          ppb
# ...          ...           ...                   ...     ...          ...
# 16117     671118           386            Ozone (O3)    Mean          ppb
# 16118     671119           386            Ozone (O3)    Mean          ppb
# 16119     671120           386            Ozone (O3)    Mean          ppb
# 16120     671121           386            Ozone (O3)    Mean          ppb
# 16121     671122           386            Ozone (O3)    Mean          ppb
#
#       Geo Type Name  Geo Join ID                          Geo Place Name  \
# 0                CD          313                     Coney Island (CD13)
# 1                CD          313                     Coney Island (CD13)
# 2           Borough            1                                   Bronx
# 3           Borough            1                                   Bronx
# 4                CD          211        Morris Park and Bronxdale (CD11)
# ...             ...          ...                                     ...
# 16117            CD          306    Park Slope and Carroll Gardens (CD6)
# 16118            CD          305   East New York and Starrett City (CD5)
# 16119            CD          304                          Bushwick (CD4)
# 16120            CD          303                Bedford Stuyvesant (CD3)
# 16121            CD          302  Fort Greene and Brooklyn Heights (CD2)
#
#           Time Period  Start_Date  Data Value
# 0         Summer 2013  06/01/2013       34.64
# 1         Summer 2014  06/01/2014       33.22
# 2         Summer 2013  06/01/2013       31.25
# 3         Summer 2014  06/01/2014       31.15
# 4      Winter 2008-09  12/01/2008        5.89
# ...               ...         ...         ...
# 16117     Summer 2020  06/01/2020       28.70
# 16118     Summer 2020  06/01/2020       29.56
# 16119     Summer 2020  06/01/2020       29.65
# 16120     Summer 2020  06/01/2020       29.28
# 16121     Summer 2020  06/01/2020       28.93
#
# [16122 rows x 11 columns]

# %% [markdown]
# ## Reindexación

# %%
df_3 = df_Dropped.copy()
df_3
# Out:
#        Unique ID  Indicator ID                  Name Measure Measure Info  \
# 0         216498           386            Ozone (O3)    Mean          ppb
# 1         216499           386            Ozone (O3)    Mean          ppb
# 2         219969           386            Ozone (O3)    Mean          ppb
# 3         219970           386            Ozone (O3)    Mean          ppb
# 4         164876           383  Sulfur Dioxide (SO2)    Mean          ppb
# ...          ...           ...                   ...     ...          ...
# 16117     671118           386            Ozone (O3)    Mean          ppb
# 16118     671119           386            Ozone (O3)    Mean          ppb
# 16119     671120           386            Ozone (O3)    Mean          ppb
# 16120     671121           386            Ozone (O3)    Mean          ppb
# 16121     671122           386            Ozone (O3)    Mean          ppb
#
#       Geo Type Name  Geo Join ID                          Geo Place Name  \
# 0                CD          313                     Coney Island (CD13)
# 1                CD          313                     Coney Island (CD13)
# 2           Borough            1                                   Bronx
# 3           Borough            1                                   Bronx
# 4                CD          211        Morris Park and Bronxdale (CD11)
# ...             ...          ...                                     ...
# 16117            CD          306    Park Slope and Carroll Gardens (CD6)
# 16118            CD          305   East New York and Starrett City (CD5)
# 16119            CD          304                          Bushwick (CD4)
# 16120            CD          303                Bedford Stuyvesant (CD3)
# 16121            CD          302  Fort Greene and Brooklyn Heights (CD2)
#
#           Time Period  Start_Date  Data Value
# 0         Summer 2013  06/01/2013       34.64
# 1         Summer 2014  06/01/2014       33.22
# 2         Summer 2013  06/01/2013       31.25
# 3         Summer 2014  06/01/2014       31.15
# 4      Winter 2008-09  12/01/2008        5.89
# ...               ...         ...         ...
# 16117     Summer 2020  06/01/2020       28.70
# 16118     Summer 2020  06/01/2020       29.56
# 16119     Summer 2020  06/01/2020       29.65
# 16120     Summer 2020  06/01/2020       29.28
# 16121     Summer 2020  06/01/2020       28.93
#
# [16122 rows x 11 columns]

# %%
def revisar_secuencia_index():
    indices_actuales = df_3.index
    #Crear una secuencia esperada (por ejemplo, una secuencia numérica)
    secuencia_esperada = pd.Index(range(indices_actuales.min(), indices_actuales.max() + 1))

    # Comparar
    if indices_actuales.equals(secuencia_esperada):
        print("La secuencia de índices es la esperada.")
    else:
        print("La secuencia de índices ha cambiado.")

# %%
revisar_secuencia_index()
# Out:
# La secuencia de índices es la esperada.

# %%
df_3.reset_index(drop = True)
# Out:
#        Unique ID  Indicator ID                  Name Measure Measure Info  \
# 0         216498           386            Ozone (O3)    Mean          ppb
# 1         216499           386            Ozone (O3)    Mean          ppb
# 2         219969           386            Ozone (O3)    Mean          ppb
# 3         219970           386            Ozone (O3)    Mean          ppb
# 4         164876           383  Sulfur Dioxide (SO2)    Mean          ppb
# ...          ...           ...                   ...     ...          ...
# 16117     671118           386            Ozone (O3)    Mean          ppb
# 16118     671119           386            Ozone (O3)    Mean          ppb
# 16119     671120           386            Ozone (O3)    Mean          ppb
# 16120     671121           386            Ozone (O3)    Mean          ppb
# 16121     671122           386            Ozone (O3)    Mean          ppb
#
#       Geo Type Name  Geo Join ID                          Geo Place Name  \
# 0                CD          313                     Coney Island (CD13)
# 1                CD          313                     Coney Island (CD13)
# 2           Borough            1                                   Bronx
# 3           Borough            1                                   Bronx
# 4                CD          211        Morris Park and Bronxdale (CD11)
# ...             ...          ...                                     ...
# 16117            CD          306    Park Slope and Carroll Gardens (CD6)
# 16118            CD          305   East New York and Starrett City (CD5)
# 16119            CD          304                          Bushwick (CD4)
# 16120            CD          303                Bedford Stuyvesant (CD3)
# 16121            CD          302  Fort Greene and Brooklyn Heights (CD2)
#
#           Time Period  Start_Date  Data Value
# 0         Summer 2013  06/01/2013       34.64
# 1         Summer 2014  06/01/2014       33.22
# 2         Summer 2013  06/01/2013       31.25
# 3         Summer 2014  06/01/2014       31.15
# 4      Winter 2008-09  12/01/2008        5.89
# ...               ...         ...         ...
# 16117     Summer 2020  06/01/2020       28.70
# 16118     Summer 2020  06/01/2020       29.56
# 16119     Summer 2020  06/01/2020       29.65
# 16120     Summer 2020  06/01/2020       29.28
# 16121     Summer 2020  06/01/2020       28.93
#
# [16122 rows x 11 columns]

# %%
df_3.reset_index()
# Out:
#        index  Unique ID  Indicator ID                  Name Measure  \
# 0          0     216498           386            Ozone (O3)    Mean
# 1          1     216499           386            Ozone (O3)    Mean
# 2          2     219969           386            Ozone (O3)    Mean
# 3          3     219970           386            Ozone (O3)    Mean
# 4          4     164876           383  Sulfur Dioxide (SO2)    Mean
# ...      ...        ...           ...                   ...     ...
# 16117  16117     671118           386            Ozone (O3)    Mean
# 16118  16118     671119           386            Ozone (O3)    Mean
# 16119  16119     671120           386            Ozone (O3)    Mean
# 16120  16120     671121           386            Ozone (O3)    Mean
# 16121  16121     671122           386            Ozone (O3)    Mean
#
#       Measure Info Geo Type Name  Geo Join ID  \
# 0              ppb            CD          313
# 1              ppb            CD          313
# 2              ppb       Borough            1
# 3              ppb       Borough            1
# 4              ppb            CD          211
# ...            ...           ...          ...
# 16117          ppb            CD          306
# 16118          ppb            CD          305
# 16119          ppb            CD          304
# 16120          ppb            CD          303
# 16121          ppb            CD          302
#
#                                Geo Place Name     Time Period  Start_Date  \
# 0                         Coney Island (CD13)     Summer 2013  06/01/2013
# 1                         Coney Island (CD13)     Summer 2014  06/01/2014
# 2                                       Bronx     Summer 2013  06/01/2013
# 3                                       Bronx     Summer 2014  06/01/2014
# 4            Morris Park and Bronxdale (CD11)  Winter 2008-09  12/01/2008
# ...                                       ...             ...         ...
# 16117    Park Slope and Carroll Gardens (CD6)     Summer 2020  06/01/2020
# 16118   East New York and Starrett City (CD5)     Summer 2020  06/01/2020
# 16119                          Bushwick (CD4)     Summer 2020  06/01/2020
# 16120                Bedford Stuyvesant (CD3)     Summer 2020  06/01/2020
# 16121  Fort Greene and Brooklyn Heights (CD2)     Summer 2020  06/01/2020
#
#        Data Value
# 0           34.64
# 1           33.22
# 2           31.25
# 3           31.15
# 4            5.89
# ...           ...
# 16117       28.70
# 16118       29.56
# 16119       29.65
# 16120       29.28
# 16121       28.93
#
# [16122 rows x 12 columns]

# %% [markdown]
# ## Renombrar Columnas

# %%
column_name_mapping = {
'Unique ID': 'ID ', 
'Indicator ID': 'ID Indicador', 
'Name':'Tipo Contaminante', 
'Measure': 'Medida', 
'Measure Info': 'Info Medida',
'Geo Type Name': 'Tipo Geografico', 
'Geo Join ID': 'ID Geografico', 
'Geo Place Name' :'Lugar Geografico' , 
'Time Period': 'Periodo Tiempo' ,
'Start_Date': 'Fecha Inicio', 
'Data Value': 'Valor'
}

# %%
df_rename = df_3.rename(columns= column_name_mapping)
df_rename.head(5)
# Out:
#       ID   ID Indicador     Tipo Contaminante Medida Info Medida  \
# 0  216498           386            Ozone (O3)   Mean         ppb
# 1  216499           386            Ozone (O3)   Mean         ppb
# 2  219969           386            Ozone (O3)   Mean         ppb
# 3  219970           386            Ozone (O3)   Mean         ppb
# 4  164876           383  Sulfur Dioxide (SO2)   Mean         ppb
#
#   Tipo Geografico  ID Geografico                  Lugar Geografico  \
# 0              CD            313               Coney Island (CD13)
# 1              CD            313               Coney Island (CD13)
# 2         Borough              1                             Bronx
# 3         Borough              1                             Bronx
# 4              CD            211  Morris Park and Bronxdale (CD11)
#
#    Periodo Tiempo Fecha Inicio  Valor
# 0     Summer 2013   06/01/2013  34.64
# 1     Summer 2014   06/01/2014  33.22
# 2     Summer 2013   06/01/2013  31.25
# 3     Summer 2014   06/01/2014  31.15
# 4  Winter 2008-09   12/01/2008   5.89
